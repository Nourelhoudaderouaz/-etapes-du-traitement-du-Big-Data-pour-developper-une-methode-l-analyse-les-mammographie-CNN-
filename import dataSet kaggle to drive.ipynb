# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
#Installation package kaggle
! pip install -q kaggle

# %%
#Création un donssier kaggle
# !mkdir ~/.kaggle/

# %%
#copie kaggle.json dans le dossier kaggle 
! cp '/content/drive/MyDrive/kaggle/kaggle.json' ~/.kaggle/

# %%
#donner les droits à kaggle.json
! chmod 600 ~/.kaggle/kaggle.json

# %%
! kaggle datasets list

# %%
! kaggle datasets download -d theoviel/rsna-breast-cancer-512-pngs
# Out:
# ...
# 100% 3.49G/3.50G [00:42<00:00, 110MB/s]
# 100% 3.50G/3.50G [00:42<00:00, 88.7MB/s]

# %%
! unzip /content/rsna-breast-cancer-512-pngs.zip -d DataSet-rsna-breast-cancer-512-pngs.zip
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
#   inflating: DataSet-rsna-breast-cancer-512-pngs.zip/63617_159110654.png
#   inflating: DataSet-rsna-breast-cancer-512-pngs.zip/63617_1855699072.png
#   inflating: DataSet-rsna-breast-cancer-512-pngs.zip/63617_1917877119.png
#   inflating: DataSet-rsna-breast-cancer-512-pngs.zip/63617_887426674.png
#   inflating: DataSet-rsna-breast-cancer-512-pngs.zip/63623_1186739164.png
#   inflating: DataSet-rsna-breast-cancer-512-pngs.zip/63623_1657034655.png
#   inflating: DataSet-rsna-breast-cancer-512-pngs.zip/63623_335778602.png
#   inflating: DataSet-rsna-breast-cancer-512-pngs.zip/63623_625719002.png
#   inflating: DataSet-rsna-breast-cancer-512-pngs.zip/63626_1154699412.png
#   inflating: DataSet-rsna-breast-cancer-512-pngs.zip/63626_549972940.png
#   inflating: DataSet-rsna-breast-cancer-512-pngs.zip/63626_599167493.png
#   inflating: DataSet-rsna-breast-cancer-512-pngs.zip/63626_939566995.png
# ...
